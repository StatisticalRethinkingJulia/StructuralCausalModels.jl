# %%
using StructuralCausalModels
using GraphRecipes, Plots
# Out:
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1278

# %%
d_string = "dag {A -> {E Z}; B -> {D Z}; Z -> {D E}; E -> D}"
# Out:
# "dag {A -> {E Z}; B -> {D Z}; Z -> {D E}; E -> D}"

# %%
dag = DAG("conf_triangles", d_string);

# %%
dag.d
# Out:
# OrderedDict{Union{Array{Symbol,1}, Symbol},Union{Array{Symbol,1}, Symbol}} with 4 entries:
#   :D       => :E
#   [:D, :E] => :Z
#   [:D, :Z] => :B
#   [:E, :Z] => :A

# %%
graphplot(dag.e, names=names(dag.e, 1), curvature_scalar=0.0, nodesize=0.2,
  method=:spring, fontsize=10, arrow=1.0, nodeshape=:circle)
